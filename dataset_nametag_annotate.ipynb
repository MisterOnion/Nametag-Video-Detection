# %% [markdown]
# # Label images using Label-studio start

# %% [markdown]
# Images count with nametag from extracted frames
#
# 153-158\
# 168-171\
# 186\
# 270-275\
# 282-288\
# 297-302\
# 308-314\
# 323-329\
# 337-342\
# 353-357\
# 368-374\
# 385-390\
# 400-404\
# 413
#
# Total = 68 nametag images from 448 frames (after labeled)

# %%
# https://www.youtube.com/watch?v=r0RspiLG260
'''
use Anaconda to create a new env for label studio
Else it will try to uninstall your env current libraries lel

1. Go to Anaconda Navigator, Create an env, and open it in terminal
2. In terminal for the env, type "pip install label-studio"
3. Once done installing, type "label-studio start"
4. Since this is server hosted locally, all credentials are on the computer, not on the web

Finally, you get to label your images

'''
